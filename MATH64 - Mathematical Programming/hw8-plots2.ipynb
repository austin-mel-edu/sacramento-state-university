# %% [markdown]
# ## HW8 - More plots
#
# Name: Austin Melendez

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Q1
#
# Read in the file `~/shared/math64/data/triangle.txt` and calculate the maximum path sum. No need to rewrite all the code, you can copy and modify the notes from class.

# %%
tri = np.readtxt("~/shared/math64/data/triangle.txt")

# %% [markdown]
# ## Q2
#
# ![image.png](attachment:9dd990cc-b3e3-4c5c-b64b-4f33ef9f0733.png)

# %% [markdown]
# ## Q3
#
# ![image.png](attachment:c8472778-5f6e-4f64-8220-fd95aee52ac7.png)

# %% [markdown]
# ## Q4
#
# ![image.png](attachment:bd48ce13-44b3-4447-9acc-dc1788b2c1d8.png)
#
# Generate the plot above.
# Notice that the blue circle is the standard unit circle and the green triangle is equilateral.

# %% [markdown]
# ## Q5
#
# Watch at least the first 3 minutes of the following YouTube video:
# https://www.youtube.com/watch?v=EK32jo7i5LQ
#
# Plot the prime spiral described in the video using the primes smaller than 40,000. The size of the markers should be s=0.5. How many spirals can you distinguish?

# %% [markdown]
# Plot the prime spiral described in the video using the primes smaller than 500,000. The size of the markers should be s=0.2. How many rays can you distinguish?
