# %% [markdown]
# ## Sequences
#
# Goal: Use while loops to explore ideas from calculus.
#
# Start by copying this file into your home directory.
#
# Claim:
#
# $$
# \lim_{n \rightarrow \infty} n \times \sin \frac{1}{n} = 1
# $$
#
# Let's verify this empirically.

# %%
# Put all your imports in the top of the notebook/script
from math import sin

# %% [markdown]
# Let's get a sense of what convergence looks like with a for loop.

# %% [markdown]
# What's the formal definition of a limit?
#
# ![image.png](attachment:4bee3c11-1da5-4c43-a47f-40e6279faf91.png)
#
# Source: [Wikipedia](https://en.wikipedia.org/wiki/Limit_of_a_sequence)

# %% [markdown]
# Let's pick $\epsilon$ and find the first number n that is within $\epsilon$ of the limit.

# %% [markdown]
# Now let's generalize this to a function that returns the first number n that is within $\epsilon$ of the limit for any value of $\epsilon$.

# %% [markdown]
# Your turn: try with a different converging sequence.
