# %%
# Install/import required libraries
suppressWarnings({
  library(tidyverse)
  library(dplyr)
  library(ggplot2)
})

# %%
df <- read_csv("pre_survey_clean.csv")
head(df)
# Out:
# Rows: 231 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (9): Survey, First Generation Status, Gender, Transfer Student, Upper v ...
# dbl (3): DID #, J_total, T_total
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   DID # Survey First Generation Status Gender Transfer Student Upper v Lower
# 1 1     Pre    Yes                     Man    Sophomore        L
# 2 2     Pre    Yes                     Man    Senior           L
# 3 3     Pre    No                      Woman  Junior           U
# 4 4     Pre    No                      Woman  Senior           U
# 5 5     Pre    Yes                     Man    Senior           L
# 6 6     Pre    No                      Woman  Senior           U
#   Race/Ethnicity  Class Level J_total T_total Major               STEM
# ...

# %%
df$Survey <- as.factor(df$Survey)
df$Gender <- as.factor(df$Gender)
df$`Transfer Student` <- as.factor(df$`Transfer Student`)
df$`Upper v Lower` <- as.factor(df$`Upper v Lower`)
df$`Race/Ethnicity` <- as.factor(df$`Race/Ethnicity`)
df$`Class Level` <- as.factor(df$`Class Level`)
df$STEM <- as.factor(df$STEM)

# %%
df
# Out:
#     DID # Survey First Generation Status Gender Transfer Student Upper v Lower
# 1    1    Pre    Yes                     Man    Sophomore        L
# 2    2    Pre    Yes                     Man    Senior           L
# 3    3    Pre    No                      Woman  Junior           U
# 4    4    Pre    No                      Woman  Senior           U
# 5    5    Pre    Yes                     Man    Senior           L
# 6    6    Pre    No                      Woman  Senior           U
# 7    7    Pre    Yes                     Woman  Sophomore        L
# 8    8    Pre    No                      Woman  Freshmen         L
# 9    9    Pre    No                      Woman  Sophomore        L
# 10  10    Pre    Yes                     Woman  Junior           L
# 11  11    Pre    No                      Woman  Senior           U
# 12  12    Pre    No                      Woman  Senior           U
# 13  13    Pre    No                      Woman  Senior           U
# ...
