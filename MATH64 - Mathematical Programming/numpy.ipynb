# %% [markdown]
# Goals:
#
# 1. Perform calculations using one dimensional arrays from numpy.
# 2. Plot simple functions using matplotlib.

# %%
# Import conventions
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Using an object from a namespace looks similar to accessing a method.

# %%
x = np.linspace(0, 6.5)
y = np.sin(x)

plt.plot(x, y)
plt.axhline(0, color = "grey", alpha = 0.2)

# %%
import sympy

# %%
sympy.pi + 1
# Out:
# 1 + pi

# %% [markdown]
# Namespaces
#
# Calling a method differs from getting an object from a namespace.
